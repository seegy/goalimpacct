# %% [markdown]
# # get in touch with the data

# %%
pip install sqlalchemy pandas psycopg2-binary
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
from sqlalchemy import create_engine, MetaData
import matplotlib.pyplot as plt

# %%
dw = 'postgresql://postgres:postgres@localhost/goalimpacct'
dw = create_engine(dw)

# %% [markdown]
# ## load and look on the data sets

# %%
matchDF      = pd.read_sql_query('select * from match',con=dw)
matchDF
# Out:
#         matchid                              tournament    matchday matchtime  \
# 0        998236                          Premier League  2003-04-26  13:30:00
# 1       2242465                        Oberliga Hamburg  2012-09-16  14:00:00
# 2       2573678                     Landesliga Hannover  2015-05-17  15:00:00
# 3       2364836                                   2.HNL  2013-10-12  15:30:00
# 4       3098247                  Eerste Klasse Amateurs  2019-03-09  20:00:00
# 5       1144082                    NRW-Liga (bis 11/12)  2012-04-07  15:00:00
# 6       2502439                        Copa MX Apertura  2014-10-23  04:15:00
# 7       2601823                            Fortuna Liga  2015-10-25  18:00:00
# 8       3076052                         Bayernliga Nord  2018-07-14  14:00:00
# 9       1127024                                 LaLiga2  2012-02-18  18:00:00
# 10      1132855                       NOFV-Oberliga Süd  2012-04-11  17:00:00
# ...

# %%
refereeDF    = pd.read_sql_query('select * from referee',con=dw)
refereeDF
# Out:
#        refereeid                refereename
# 0           4714             Mehmet Fatiras
# 1           1939                 Bernd Ihle
# 2            614                Andy D'Urso
# 3           9853               Jakov Titlic
# 4          24182           Jonas Timmermans
# 5           2263             Sven Heinrichs
# 6           4733          Óscar Macías Romo
# 7           1672               Karel Hrubes
# 8          15051         Thomas Ehrnsperger
# 9            551                 Dirk Simon
# 10          1764      José Luis Lesma López
# 11          6339           Stephan Spengler
# 12          6134               Stefan Lesko
# 13           319             Nicola Ayroldi
# 14         26638           Viktor Kopievsky
# 15          3569              Andrew Madley
# 16         20215                 Marko Linß
# 17          7235       Annette Hanf (Raith)
# 18           870             Robert Kempter
# 19          1759  Víctor Hugo Rivera Chávez
# ...

# %%
teamDF       = pd.read_sql_query('select * from team',con=dw)
teamDF
# Out:
#       teamid                    teamname
# 0       4610     SV Halstenbek-Rellingen
# 1        117       Eintracht Norderstedt
# 2       5114                 Heeßeler SV
# 3      13268                TSV Burgdorf
# 4        355            Bolton Wanderers
# 5         11                  FC Arsenal
# 6        314        HNK Cibalia Vinkovci
# 7      11083                    NK Rudes
# 8       9888                   KSK Heist
# 9       2715                 RFC Seraing
# 10      5263             TuS Erndtebrück
# 11      3957                TuS Dornberg
# 12      7055                 Tigres UANL
# 13      1804            Deportivo Toluca
# 14       197              AC Sparta Prag
# 15       715      FC Bohemians Prag 1905
# 16     16002       Würzburger Kickers II
# 17       615               SpVgg Ansbach
# 18      7081       FC Carl Zeiss Jena II
# 19       275                 FSV Zwickau
# 20      3302                  UD Almería
# 21       171                 Real Murcia
# ...

# %%
cardDF       = pd.read_sql_query('select * from card',con=dw)
cardDF
# Out:
#          matchid  teamid  playerid  time      color
# 0         998236     355      3888    31     yellow
# 1         998236     355      3274    60     yellow
# 2         998236     355      3888    89  yellowred
# 3         998236      11      3207    33     yellow
# 4         998236      11      3208    80     yellow
# 5        2364836     314    217751    48     yellow
# 6        2364836     314     71593    56     yellow
# 7        2364836     314     60714    57     yellow
# 8        2364836     314    217751    68  yellowred
# 9        2364836     314     72115    88     yellow
# 10       2364836   11083    286807    48     yellow
# 11       2364836   11083    144892    70     yellow
# 12       2364836   11083     69419    79     yellow
# 13       3098247    9888    317660    30     yellow
# 14       3098247    9888    419096    73     yellow
# 15       3098247    2715    378225    53     yellow
# 16       3098247    2715    127018    75     yellow
# ...

# %%
scoreDF      = pd.read_sql_query('select * from scores',con=dw)
scoreDF
# Out:
#          playerid  matchid target-match-timestamp  teamid  \
# 0               0  2506759             2014-10-22   39591
# 1               0  2539097             2014-08-06   19221
# 2               0  2604656             2015-08-10   18026
# 3               1  1070920             2000-04-16     151
# 4               3    16357             1993-09-01      79
# 5               4    18391             2000-04-02       2
# 6               6    17617             1997-10-04      80
# 7               6    31562             2006-02-03     110
# 8               7   940759             2000-09-21       2
# 9               7  2235339             2012-09-25     446
# 10              8  1170017             1995-09-12     156
# 11             10    18913             2001-12-16       2
# 12             10  1089278             1999-04-01     459
# 13             11    18492             2000-09-15       2
# 14             11    31736             2006-04-22      52
# ...

# %%
playertimeDF = pd.read_sql_query('select * from playertime',con=dw)
playertimeDF
# Out:
#          playerid  matchid  teamid  in-time  out-time  playtime
# 0             4.0    18660       2        0      67.0        67
# 1            10.0    69250      27        0      46.0        46
# 2            10.0  1070600     151        0      46.0        46
# 3            24.0    31331      18        0      52.0        52
# 4            39.0    42648     158        0      87.0        87
# 5            40.0    69056      52        0      86.0        86
# 6            48.0    20183       3        0      77.0        77
# 7            65.0  2482261     162        0      72.0        72
# 8            66.0    31807      42        0      70.0        70
# 9            74.0    18436      15        0      72.0        72
# 10           81.0    69832      18        0      81.0        81
# 11           85.0  3134193     828        0      85.0        85
# 12           91.0   951163      95        0      60.0        60
# 13           97.0  2762827    2035        0      46.0        46
# ...

# %%
profileDF    = pd.read_sql_query('select * from profile',con=dw)
profileDF
# Out:
#        playerid              playername   birthdate  nationality  \
# 0        146189         Miroslav Enchev  1991-08-08    Bulgarien
# 1        217030            Idan Mikdash  1991-09-09       Israel
# 2        240098        Bonniek Martínez  1987-11-05   Costa Rica
# 3        288147           Yasiz Zaanani        None        k. A.
# 4        216435              Ulf Möller        None  Deutschland
# 5        532782         Havard Meinseth  1998-12-11     Norwegen
# 6         70446          Ismael Nielsen  1987-09-14     Dänemark
# 7        149777           André Skiadas  1985-03-14      Ecuador
# 8        216957             Adrián Díaz  1993-06-02      Uruguay
# 9        339513        Petar Velickovic  1992-06-22      Serbien
# 10       117692         Andreas Gotwich        None  Deutschland
# 11        75643  Christoffer Viktorsson  1989-03-22     Schweden
# 12       492802        Markus Plaickner  1976-01-12   Österreich
# ...

# %% [markdown]
# ## lets check what includes the data

# %% [markdown]
# ### in which saisons?

# %%
bysaison = matchDF.groupby(['saison']).size() 

plt.figure()
bysaison.plot(kind='bar',figsize=(15,7), title="Matches by saison");

# %% [markdown]
# ### from which coutry?

# %%
bycountry = matchDF.groupby(['country']).size().sort_values(ascending=False).head(30)

plt.figure()
bycountry.plot(kind='bar',figsize=(15,7), title="Matches by country");

# %% [markdown]
# ### from which  tournament?

# %%
bytour = matchDF.groupby(['tournament', 'country']).size().sort_values(ascending=False).head(30)

plt.figure()
bytour.plot(kind='bar',figsize=(15,7), title="Matches by tournament(country)");

# %% [markdown]
# ### we have referees?

# %%
matchRefereeDF =  pd.merge(matchDF, refereeDF, on='refereeid')
byreferee = matchRefereeDF.groupby(['refereeid', 'refereename']).size().sort_values(ascending=False).head(20)

plt.figure()
byreferee.plot(kind='bar',figsize=(15,7), title="Matches by referee");

# %% [markdown]
# ### which teams?

# %%
matchGuestDF = matchDF[['matchid', 'guestteam']].rename(columns={"guestteam": "teamid"})
matchHomeDF = matchDF[['matchid', 'hometeam']].rename(columns={"hometeam": "teamid"})

matchTeamDF = pd.merge( pd.concat([matchGuestDF, matchHomeDF]), teamDF, on="teamid")

byTeam = matchTeamDF.groupby(['teamid', 'teamname']).size().sort_values(ascending=False).head(20)

plt.figure()
byTeam.plot(kind='bar',figsize=(15,7), title="Matches by team (home and guest)")

# %% [markdown]
# ##  can we check favourite and hate teams of referees by cards?
# ### Whats the biggest average difference between all referees and one specific referee by team? (More cards)

# %%
targetSeasions = ['2019', '2018', '2017', '2016', '2015', \
                  '2014', '2013', '2012', '2011', '2010']

blLastXYearsDF = matchDF[  (matchDF['tournament'] == '1. Bundesliga') 
                         & (matchDF['saison'].isin(targetSeasions))]


bllXyguestDF = blLastXYearsDF[['matchid', 'guestteam', 'refereeid']].rename(columns={"guestteam": "teamid"})
bllXyhomeDF = blLastXYearsDF[['matchid', 'hometeam', 'refereeid']].rename(columns={"hometeam": "teamid"})

bllXyTeamDF = pd.concat([bllXyguestDF, bllXyhomeDF])


cardsAndMatchTeamsDF = pd.merge(bllXyTeamDF, cardDF, on=['matchid','teamid'])

cardCountPerMatch = pd.DataFrame({
    'count' : cardsAndMatchTeamsDF.groupby(['refereeid', 'teamid', 'matchid']).size()}).reset_index()

avgCardsPerTeamAndReferee = pd.DataFrame({
    'avgReferee' : cardCountPerMatch.groupby(['refereeid', 'teamid'])['count'].mean()}).reset_index()

avgCardsPerTeam = pd.DataFrame({
    'avgTeam' : avgCardsPerTeamAndReferee.groupby(['teamid'])['avgReferee'].mean()}).reset_index()

refereeMatchCount = pd.DataFrame({ 'matchCount' : bllXyTeamDF.groupby(['refereeid', 'teamid']).size()}).reset_index()

diffCards = pd.merge(avgCardsPerTeam, avgCardsPerTeamAndReferee, on="teamid")
diffCards = pd.merge(diffCards, refereeMatchCount)
diffCards = diffCards[diffCards['matchCount'] > 2]
diffCards['diff'] = diffCards['avgReferee'] - diffCards['avgTeam']
diffCards['diff_max'] = diffCards.groupby(['refereeid'])['diff'].transform(max)
diffCards['diff_min'] = diffCards.groupby(['refereeid'])['diff'].transform(min)

refereesMostCards = diffCards[diffCards['diff_max'] == diffCards['diff']][['refereeid', 'teamid', 'diff', 'matchCount']] 

refereesMostCards = pd.merge(pd.merge(refereesMostCards, teamDF, on='teamid'), \
        refereeDF, \
        on='refereeid').sort_values(by=['diff'], ascending=False)

refereesMostCards
# Out:
#     refereeid   teamid      diff  matchCount                  teamname  \
# 12      753.0     27.0  1.951111           8         FC Bayern München
# 33     1832.0    533.0  1.727529           3       TSG 1899 Hoffenheim
# 14      789.0     33.0  1.641820           3             FC Schalke 04
# 27       10.0    105.0  1.424242           3           SV Darmstadt 98
# 32      729.0    533.0  1.394196           4       TSG 1899 Hoffenheim
# 13      685.0     33.0  1.375153           5             FC Schalke 04
# 17     1940.0     39.0  1.360789           3            1.FSV Mainz 05
# 21      107.0     60.0  1.296985           4               SC Freiburg
# 35       48.0  23826.0  1.296296           5    RasenBallsport Leipzig
# 26      124.0     82.0  1.262988          15             VfL Wolfsburg
# 6       732.0     15.0  1.190901           4       Bayer 04 Leverkusen
# 18        4.0     42.0  1.189960           9               Hannover 96
# ...

# %% [markdown]
# ### (lesser cards)

# %%
refereesLeastCards = diffCards[diffCards['diff_min'] == diffCards['diff']][['refereeid', 'teamid', 'diff', 'matchCount']] 

refereesLeastCards = pd.merge(pd.merge(refereesLeastCards, teamDF, on='teamid'), \
        refereeDF, \
        on='refereeid').sort_values(by=['diff'], ascending=True)

refereesLeastCards
# Out:
#     refereeid   teamid      diff  matchCount                teamname  \
# 0       124.0      2.0 -1.393519           3     1.FC Kaiserslautern
# 1        10.0      3.0 -1.287701          10               1.FC Köln
# 4        39.0      4.0 -1.107839           6           1.FC Nürnberg
# 25       34.0     86.0 -1.090190           8        SV Werder Bremen
# 9        47.0     27.0 -1.048889           4       FC Bayern München
# 35        4.0  23826.0 -0.953704           3  RasenBallsport Leipzig
# 33      880.0    533.0 -0.939137           3     TSG 1899 Hoffenheim
# 32       86.0    533.0 -0.939137           3     TSG 1899 Hoffenheim
# 8        23.0     27.0 -0.882222          10       FC Bayern München
# 34      121.0   4795.0 -0.877778           3        FC Ingolstadt 04
# 24      729.0     82.0 -0.871627           7           VfL Wolfsburg
# 23      110.0     82.0 -0.871627           4           VfL Wolfsburg
# 21      173.0     60.0 -0.869681           4             SC Freiburg
# ...

# %% [markdown]
# ## and otherwise? when game will be lead by referee x, against which club you will get me most cards?

# %% [markdown]
# ## So what are the favourite and hate team of each referee?

# %%
refereesFavTeam = refereesLeastCards[['refereeid', 'refereename','teamname']] \
                        .rename(columns={'teamname': 'Favourite Team'})
refereesHateteam = refereesMostCards[['refereeid', 'refereename','teamname']] \
                        .rename(columns={'teamname': 'Hate Team'})

refereesFavHateTeam = pd.merge(refereesFavTeam, refereesHateteam, on=['refereeid', 'refereename']).drop(columns=['refereeid'])

refereesFavHateTeam = refereesFavHateTeam[refereesFavHateTeam['Hate Team'] != refereesFavHateTeam['Favourite Team']] \
                        .rename(columns={'refereename': 'Referee'})

refereesFavHateTeam
# Out:
#               Referee          Favourite Team                 Hate Team
# 0        Felix Zwayer     1.FC Kaiserslautern             VfL Wolfsburg
# 1      Wolfgang Stark               1.FC Köln           SV Darmstadt 98
# 2      Markus Schmidt           1.FC Nürnberg                 1.FC Köln
# 3         Günter Perl        SV Werder Bremen             VfB Stuttgart
# 4         Tobias Welz       FC Bayern München                 1.FC Köln
# 5        Manuel Gräfe  RasenBallsport Leipzig               Hannover 96
# 6     Martin Petersen     TSG 1899 Hoffenheim  Borussia Mönchengladbach
# 8     Peter Gagelmann       FC Bayern München       TSG 1899 Hoffenheim
# 9    Frank Willenborg        FC Ingolstadt 04            1.FSV Mainz 05
# 10    Benjamin Cortus           VfL Wolfsburg       TSG 1899 Hoffenheim
# 11  Dr. Robert Kampka           VfL Wolfsburg                 1.FC Köln
# 12  Markus Wingenbach             SC Freiburg       TSG 1899 Hoffenheim
# ...

# %% [markdown]
# ## which player has the most playtime (per tournament and saison)

# %%
matchAndtimes = pd.merge(matchDF[(pd.to_numeric(matchDF['saison'], errors='coerce') >= 2015)], \
                         playertimeDF)
matchAndtimes
# Out:
#          matchid              tournament    matchday matchtime  hometeam  \
# 0        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 1        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 2        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 3        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 4        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 5        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 6        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 7        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 8        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 9        3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 10       3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# 11       3098247  Eerste Klasse Amateurs  2019-03-09  20:00:00    9888.0
# ...

# %%
playerTimesPerTS = matchAndtimes.groupby(['tournament', 'saison', 'playerid'])['playtime'].sum().reset_index()
playerTimesPerTS['playtime_max'] = playerTimesPerTS.groupby(['tournament', 'saison'])['playtime'].transform(max)
playerTimesPerTS = playerTimesPerTS[ playerTimesPerTS['playtime'] == playerTimesPerTS['playtime_max'] ] \
                        .drop(columns=['playtime'])
#playerTimesPerTS

# %% [markdown]
# ## How often relates which position to the player with the most playtime per tournament and saison?

# %%
playerDetails = pd.merge(playerTimesPerTS, profileDF) \
                                     .drop(columns=['birthdate', 'nationality', 'playerid'])

positionTimesMaxPT  =  pd.DataFrame({'count' : playerDetails
                                     .groupby(['position']).size()}).reset_index()

#positionTimesMaxPT

# %%
fig1, ax1 = plt.subplots()
ax1.pie(positionTimesMaxPT['count'], labels=positionTimesMaxPT['position'], autopct='%1.1f%%',
        shadow=True, startangle=90, radius=2.5)

1 #avoid plt outpout
# Out:
# 1

# %%
positionmapper = {
    "Abwehr" : "Abwehr",
    "Mittelfeld" : "Mittelfeld",
    "Sturm" : "Sturm",
    "Torwart": "Torwart",
    "Defensives Mittelfeld" : "Mittelfeld",
    "Hängende Spitze" : "Sturm",
    "Innenverteidiger" : "Abwehr",
    "Libero" : "Abwehr",
    "Linker Verteidiger" : "Abwehr",
    "Linksaußen" : "Sturm",
    "Mittelstürmer" : "Mittelfeld",
    "Offensives Mittelfeld" : "Mittelfeld",
    "Rechter Verteidiger" : "Abwehr",
    "Rechtes Mittelfeld" : "Mittelfeld",
    "Rechtsaußen" : "Sturm",
    "Zentrales Mittelfeld" : "Mittelfeld",
    "Linkes Mittelfeld" : "Mittelfeld"
}

# %%
playerDetails = pd.merge(playerTimesPerTS, profileDF) \
                                     .drop(columns=['birthdate', 'nationality', 'playerid'])

playerDetails["positionKind"] = playerDetails["position"].map(positionmapper)


positionKindTimesMaxPT  =  pd.DataFrame({'count' : playerDetails
                                     .groupby(['positionKind']).size()}).reset_index()

#positionKindTimesMaxPT

# %%
fig1, ax1 = plt.subplots()
ax1.pie(positionKindTimesMaxPT['count'], labels=positionKindTimesMaxPT['positionKind'], autopct='%1.1f%%',
        shadow=True, startangle=90, radius=2.5)

1 #avoid plt outpout
# Out:
# 1

# %% [markdown]
# ## To compare: what are the average playtimes of positions / position kinds?

# %%
singlePlayerTimes = matchAndtimes.groupby(['playerid'])['playtime'].mean().reset_index()

singlePlayerDetails = pd.merge(singlePlayerTimes, profileDF) \
                                     .drop(columns=['playername', 'birthdate', 'nationality', 'playerid'])

singlePlayerDetails = singlePlayerDetails.groupby(['position'])['playtime'].mean().sort_values(ascending=False)

#singlePlayerDetails

# %%
plt.figure()
singlePlayerDetails.plot(kind='bar',figsize=(15,7), title="average playtimes per position")

# %%
singlePlayerTimes = matchAndtimes.groupby(['playerid'])['playtime'].mean().reset_index()

singlePlayerDetails = pd.merge(singlePlayerTimes, profileDF) \
                                     .drop(columns=['playername', 'birthdate', 'nationality', 'playerid'])

singlePlayerDetails["positionKind"] = singlePlayerDetails["position"].map(positionmapper)


singlePlayerDetails = singlePlayerDetails.groupby(['positionKind'])['playtime'].mean().sort_values(ascending=False)

#singlePlayerDetails

# %%
plt.figure()
singlePlayerDetails.plot(kind='bar',figsize=(15,7), title="average playtimes per position kind")
